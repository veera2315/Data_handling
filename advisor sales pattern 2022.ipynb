# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#adv_2021= pd.read_excel("C:/Users/EFRNV/Downloads/Advisor analasis Norman_req_India/India Advisor Details 2021.xlsx",'Sheet 1')
adv_2022= pd.read_excel("C:/Users/EFRNV/Downloads/Advisor analasis Norman_req_India/India Advisor Details 2022.xlsx")

# %%
adv_2022.columns
# Out:
# Index(['index', 'Advisor name', 'Retailer Name', 'Retailer ID', 'Advisor ID',
#        'Month of Order Intent Created Date', 'Advisor Phone Number',
#        'Country Code ', 'Hierarchy Level 3', 'Hierarchy Level 2',
#        'Hierarchy Level 1', 'Advisor Type', 'Product category',
#        'Product Brand', 'Product Name', 'Unit', 'Total Order Intents',
#        'Distinct count of Cancelled Order Intents', 'Farmers with Intent',
#        'Farmers with multiple Intents', 'Farmers with Purchase',
#        'Distinct count of Farmers with multiple purchases',
#        'Farmer Conversion', 'Active Retailers', 'Volume Intent',
#        'Volume Cancelled', 'Volume Purchased', 'Returned Volume',
#        'Avg Volume Sold per Farmers', 'Total Intent Value',
#        'Cancelled Order Value', 'Sales Value', 'Avg Sales per Farmer',
#        'Actual Commission', 'Intended Commission'],
#       dtype='object')

# %%
adv_2022.head()
# Out:
#   index Advisor name Retailer Name Retailer ID Advisor ID
# 0     4   A Nagaraju           NaN         NaN   47071 IN  \
# 1     5   A Nagaraju           NaN         NaN   47071 IN
# 2    27   A Nagaraju     Rytudepot  AP06642 IN   47071 IN
# 3    28   A Nagaraju     Rytudepot  AP06642 IN   47071 IN
# 4    29   A Nagaraju     Rytudepot  AP06642 IN   47071 IN
#
#   Month of Order Intent Created Date  Advisor Phone Number Country Code
# 0                            January            9000696331            IN  \
# 1                            January            9000696331            IN
# 2                            January            9000696331            IN
# 3                            January            9000696331            IN
# 4                            January            9000696331            IN
#
#   Hierarchy Level 3 Hierarchy Level 2  ... Volume Cancelled Volume Purchased
# 0               NaN               NaN  ...              6.0              0.0  \
# 1               NaN               NaN  ...              0.0              0.0
# 2               NaN               NaN  ...              0.0             20.0
# 3               NaN               NaN  ...              0.0             10.0
# 4               NaN               NaN  ...              0.0             10.0
#
#   Returned Volume Avg Volume Sold per Farmers Total Intent Value
# 0             0.0                    0.000000            12588.0  \
# 1             0.0                    0.000000             2290.0
# 2             0.0                   10.000000            27600.0
# 3             0.0                    5.000000            18750.0
# 4             0.0                    3.333333            19160.0
#
#   Cancelled Order Value  Sales Value  Avg Sales per Farmer  Actual Commission
# 0               12588.0          0.0                   NaN                0.0  \
# 1                   0.0          0.0                   NaN                0.0
# 2                   0.0      27600.0          13800.000000              680.0
# 3                   0.0      18750.0           9375.000000              470.0
# 4                   0.0      19160.0           6386.666667              480.0
#
#    Intended Commission
# 0                312.0
# 1                 50.0
# 2                680.0
# 3                470.0
# 4                480.0
#
# [5 rows x 35 columns]

# %%
adv_2022.describe()
# Out:
#        Advisor Phone Number  Total Order Intents
# count          1.826710e+05        182671.000000  \
# mean           8.847165e+09             3.570671
# std            1.030123e+09            10.172483
# min            6.000069e+09             1.000000
# 25%            8.144571e+09             1.000000
# 50%            9.143571e+09             1.000000
# 75%            9.667357e+09             3.000000
# max            9.998675e+09          1510.000000
#
#        Distinct count of Cancelled Order Intents  Farmers with Intent
# count                              182671.000000        182671.000000  \
# mean                                    0.082805             3.449978
# std                                     0.575933             9.823412
# min                                     0.000000             1.000000
# 25%                                     0.000000             1.000000
# 50%                                     0.000000             1.000000
# 75%                                     0.000000             3.000000
# max                                    66.000000          1483.000000
#
#        Farmers with multiple Intents  Farmers with Purchase
# count                  182671.000000          182671.000000  \
# mean                        1.366008               2.518823
# std                         3.549105               8.532742
# min                         0.000000               0.000000
# 25%                         0.000000               0.000000
# 50%                         1.000000               1.000000
# 75%                         1.000000               2.000000
# max                       260.000000            1483.000000
#
#        Distinct count of Farmers with multiple purchases  Farmer Conversion
# count                                      182671.000000      182671.000000  \
# mean                                            1.321496           0.672082
# std                                             3.688234           0.468874
# min                                             0.000000           0.000000
# 25%                                             0.000000           0.000000
# 50%                                             1.000000           1.000000
# 75%                                             1.000000           1.000000
# max                                           260.000000           1.000000
#
#        Active Retailers  Volume Intent  Volume Cancelled  Volume Purchased
# count     182671.000000  153911.000000     182671.000000     182671.000000  \
# mean           0.673035      21.427379          0.813231         12.639949
# std            0.469106     200.525419         24.431834        123.022818
# min            0.000000       0.002000          0.000000          0.000000
# 25%            0.000000       0.750000          0.000000          0.000000
# 50%            1.000000       2.500000          0.000000          0.800000
# 75%            1.000000       8.750000          0.000000          4.750000
# max            1.000000   30680.000000       3848.000000      12956.000000
#
#        Returned Volume  Avg Volume Sold per Farmers  Total Intent Value
# count    182671.000000                182671.000000        1.568690e+05  \
# mean          0.005941                     3.101945        3.073421e+04
# std           0.510522                    14.295823        2.828940e+05
# min           0.000000                     0.000000        3.050000e+01
# 25%           0.000000                     0.000000        2.282000e+03
# 50%           0.000000                     0.500000        7.362000e+03
# 75%           0.000000                     2.000000        2.200000e+04
# max         160.000000                  1295.600000        7.668912e+07
#
#        Cancelled Order Value   Sales Value  Avg Sales per Farmer
# count           1.826710e+05  1.826710e+05          1.229430e+05  \
# mean            7.716844e+02  1.840619e+04          8.037835e+03
# std             1.144167e+04  7.713541e+04          1.501110e+04
# min             0.000000e+00  0.000000e+00          0.000000e+00
# 25%             0.000000e+00  0.000000e+00          1.260000e+03
# 50%             0.000000e+00  2.250000e+03          3.486000e+03
# 75%             0.000000e+00  1.240000e+04          9.102000e+03
# max             1.840000e+06  6.196075e+06          1.285200e+06
#
#        Actual Commission  Intended Commission
# count      182671.000000         1.813670e+05
# mean          456.116489         6.093771e+02
# std          1902.296027         6.450869e+03
# min             0.000000         0.000000e+00
# 25%             0.000000         2.100000e+01
# 50%            55.000000         1.200000e+02
# 75%           305.000000         4.250000e+02
# max        155550.000000         1.925250e+06

# %%
adv_2022.nunique()
# Out:
# index                                                182671
# Advisor name                                           3767
# Retailer Name                                          6230
# Retailer ID                                            6318
# Advisor ID                                             4030
# Month of Order Intent Created Date                       12
# Advisor Phone Number                                   4030
# Country Code                                              1
# Hierarchy Level 3                                         5
# Hierarchy Level 2                                        49
# Hierarchy Level 1                                       318
# Advisor Type                                             17
# Product category                                          6
# Product Brand                                            47
# Product Name                                            272
# Unit                                                      3
# Total Order Intents                                     219
# Distinct count of Cancelled Order Intents                34
# Farmers with Intent                                     211
# Farmers with multiple Intents                           112
# Farmers with Purchase                                   186
# Distinct count of Farmers with multiple purchases       112
# Farmer Conversion                                        95
# Active Retailers                                          2
# Volume Intent                                          4521
# Volume Cancelled                                        554
# Volume Purchased                                       4292
# Returned Volume                                          76
# Avg Volume Sold per Farmers                            8310
# Total Intent Value                                    15263
# Cancelled Order Value                                  2817
# Sales Value                                           13857
# Avg Sales per Farmer                                  22177
# Actual Commission                                      4696
# Intended Commission                                    4958
# dtype: int64

# %%
adv_2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 182671 entries, 0 to 182670
# Data columns (total 35 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   index                                              182671 non-null  object
#  1   Advisor name                                       182671 non-null  object
#  2   Retailer Name                                      123437 non-null  object
#  3   Retailer ID                                        123437 non-null  object
#  4   Advisor ID                                         182671 non-null  object
#  5   Month of Order Intent Created Date                 182671 non-null  object
#  6   Advisor Phone Number                               182671 non-null  int64
#  7   Country Code                                       182671 non-null  object
#  8   Hierarchy Level 3                                  168631 non-null  object
#  9   Hierarchy Level 2                                  168631 non-null  object
#  10  Hierarchy Level 1                                  168631 non-null  object
#  11  Advisor Type                                       182671 non-null  object
#  12  Product category                                   179710 non-null  object
#  13  Product Brand                                      182671 non-null  object
#  14  Product Name                                       182671 non-null  object
#  15  Unit                                               182671 non-null  object
#  16  Total Order Intents                                182671 non-null  int64
#  17  Distinct count of Cancelled Order Intents          182671 non-null  int64
#  18  Farmers with Intent                                182671 non-null  int64
#  19  Farmers with multiple Intents                      182671 non-null  int64
#  20  Farmers with Purchase                              182671 non-null  int64
#  21  Distinct count of Farmers with multiple purchases  182671 non-null  int64
#  22  Farmer Conversion                                  182671 non-null  float64
#  23  Active Retailers                                   182671 non-null  int64
#  24  Volume Intent                                      153911 non-null  float64
#  25  Volume Cancelled                                   182671 non-null  float64
#  26  Volume Purchased                                   182671 non-null  float64
#  27  Returned Volume                                    182671 non-null  float64
#  28  Avg Volume Sold per Farmers                        182671 non-null  float64
#  29  Total Intent Value                                 156869 non-null  float64
#  30  Cancelled Order Value                              182671 non-null  float64
#  31  Sales Value                                        182671 non-null  float64
#  32  Avg Sales per Farmer                               122943 non-null  float64
#  33  Actual Commission                                  182671 non-null  float64
#  34  Intended Commission                                181367 non-null  float64
# dtypes: float64(12), int64(8), object(15)
# memory usage: 48.8+ MB

# %%
print("Is there any missing data?")
print(adv_2022.isna().sum())
# Out:
# Is there any missing data?
# index                                                    0
# Advisor name                                             0
# Retailer Name                                        59234
# Retailer ID                                          59234
# Advisor ID                                               0
# Month of Order Intent Created Date                       0
# Advisor Phone Number                                     0
# Country Code                                             0
# Hierarchy Level 3                                    14040
# Hierarchy Level 2                                    14040
# Hierarchy Level 1                                    14040
# Advisor Type                                             0
# Product category                                      2961
# Product Brand                                            0
# Product Name                                             0
# Unit                                                     0
# Total Order Intents                                      0
# Distinct count of Cancelled Order Intents                0
# Farmers with Intent                                      0
# Farmers with multiple Intents                            0
# Farmers with Purchase                                    0
# Distinct count of Farmers with multiple purchases        0
# Farmer Conversion                                        0
# Active Retailers                                         0
# Volume Intent                                        28760
# Volume Cancelled                                         0
# Volume Purchased                                         0
# Returned Volume                                          0
# Avg Volume Sold per Farmers                              0
# Total Intent Value                                   25802
# Cancelled Order Value                                    0
# Sales Value                                              0
# Avg Sales per Farmer                                 59728
# Actual Commission                                        0
# Intended Commission                                   1304
# dtype: int64

# %%
# Group the data frame by 'month' and 'category' and sum the 'sales' column:

#grouped = adv_2022.groupby(['Month of Order Intent Created Date', 'Product category','Product Brand','Product Name']).sum().reset_index()
#grouped = adv_2022.groupby(['Month of Order Intent Created Date', 'Product category','Product Brand']).sum().reset_index()
grouped = adv_2022.groupby(['Month of Order Intent Created Date', 'Product category']).sum().reset_index()

# %%
# Use pivot() function to create a pivot table with 'month' as the index and 'category' as the columns:

#pivot_table = grouped.pivot(index='Month of Order Intent Created Date', columns=['Product category','Product Brand','Product Name'], values='Sales Value')
#pivot_table = grouped.pivot(index='Month of Order Intent Created Date', columns=['Product category','Product Brand'], values='Sales Value')
pivot_table = grouped.pivot(index='Month of Order Intent Created Date', columns='Product category', values='Sales Value')

# %%
# Define your pivot table first
pivot_table = pd.pivot_table(grouped, values='Sales Value', index='Month of Order Intent Created Date', columns='Product category', aggfunc=sum)
# Convert index to DateTimeIndex
#pivot_table.index = pd.to_datetime(pivot_table.index)

# Sort index in ascending order
pivot_table = pivot_table.sort_index()

# Calculate sales values and sales values in millions
sales_values = pivot_table.sum(axis=1)
sales_values_millions = [value / 1000000 for value in sales_values]

# Plot the pivot table and add labels
#plt.figure(figsize=(30, 20)) # Set the figure size here
fig, ax = plt.subplots(figsize=(15, 10))
pivot_table.plot(kind='line', ax=ax)
ax.set_xlabel('Month of Order Intent Created Date')
ax.set_ylabel('Sales Value')
ax.set_title('Sales patterns by Product category')
plt.xticks(rotation=90)

# Add labels to the plot
for i, value in enumerate(sales_values_millions):
    ax.text(i, sales_values[i]+0.005*max(sales_values), f'{value:.2f}M', ha='center', va='bottom')

# Set y-axis limits
ax.set_ylim([0, max(sales_values)*1.1])

plt.show()

# %%
plt.figure(figsize = (4,6))
grouped = adv_2022.groupby(['Product category', 'Sales Value']).sum().reset_index()

plt.pie(grouped["Product category"].value_counts(), labels = grouped["Product category"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("category Percentage")

plt.show()

# %%
plt.figure(figsize = (6,6))
grouped = adv_2022.groupby(['Month of Order Intent Created Date', 'Sales Value']).sum().reset_index()

plt.pie(grouped["Month of Order Intent Created Date"].value_counts(), labels = grouped["Month of Order Intent Created Date"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("Monthly Percentage")

plt.show()

# %%
grouped = adv_2022.groupby(['Month of Order Intent Created Date', 'Product category']).sum().reset_index()

# Define your pivot table first
pivot_table = pd.pivot_table(grouped, values='Sales Value', index='Product category', columns='Month of Order Intent Created Date', aggfunc=sum)
# Convert index to DateTimeIndex
#pivot_table.index = pd.to_datetime(pivot_table.index)

# Sort index in ascending order
pivot_table = pivot_table.sort_index()

# Calculate sales values and sales values in millions
sales_values = pivot_table.sum(axis=1)
sales_values_millions = [value / 1000000 for value in sales_values]

# Plot the pivot table and add labels
#plt.figure(figsize=(30, 20)) # Set the figure size here
fig, ax = plt.subplots(figsize=(15, 10))
pivot_table.plot(kind='line', ax=ax)
ax.set_xlabel('Product category')
ax.set_ylabel('Sales Value')
ax.set_title('Sales patterns by month')
#plt.xticks(rotation=90)

# Add labels to the plot
for i, value in enumerate(sales_values_millions):
    ax.text(i, sales_values[i]+0.005*max(sales_values), f'{value:.2f}M', ha='center', va='bottom')

# Set y-axis limits
ax.set_ylim([0, max(sales_values)*1.1])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# group the data by the values in column1 and column2, and sum the values in column3
grouped_data = adv_2022.groupby(['Hierarchy Level 3', 'Product category'])['Sales Value'].sum()

# convert the grouped data to a dataframe
grouped_data_df = grouped_data.reset_index()

# extract column1, column2, and sales_value from the dataframe
column1 = grouped_data_df['Hierarchy Level 3']
column2 = grouped_data_df['Product category']
sales_value = grouped_data_df['Sales Value']

# create a list of unique values in column1
unique_vals = column1.unique()

# create a colormap that maps each unique value to a different color
num_unique_vals = len(unique_vals)
cmap = plt.get_cmap('tab20')
colors = cmap(np.linspace(0, 1, num_unique_vals))

# create a figure and axis objects
fig, ax = plt.subplots(figsize=(8, 15))

# plot sales_value against column1 and column2, using the colormap to set the colors
for i, val in enumerate(unique_vals):
    mask = (column1 == val)
    ax.scatter(column2[mask], sales_value[mask], s=100, alpha=0.5, label=val, color=colors[i])

# add text labels for the sales value sums
for i, txt in enumerate(sales_value):
    ax.text(column2[i], sales_value[i], f'{txt/1000000:.2f}M', ha='center', va='center', color='red')

# set x and y axis labels
ax.set_xlabel('Product category')
ax.set_ylabel('Sales Value (USD millions)')

# add a legend
ax.legend(title='Hierarchy Level 3', loc='upper left')

# display the plot
plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker


def millions_formatter(x, pos):
return f"${x/1000000:.1f}M"

plt.figure(figsize=(15,6))
sns.countplot(data=adv_2022, x="Hierarchy Level 3", y="Sales Value", hue="Product category", palette="pastel")
plt.gca().yaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter)) 

plt.xlabel("Hierarchy Level 3")
plt.ylabel("Sales Value (in millions)")
plt.title("Count of Sales Values by Hierarchy Level 3 and Product Category")
plt.show()
# Out:
#   Cell In[16], line 8
#     return f"${x/1000000:.1f}M"
#     ^
# IndentationError: expected an indented block after function definition on line 7

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

grouped_data = adv_2022.groupby(['Hierarchy Level 3', 'Product category'])['Sales Value'].sum().reset_index()
sorted_data = grouped_data.sort_values(['Hierarchy Level 3', 'Product category'], ascending=True)

# Define function to format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f"${x/1000000:.1f}M"

# Create the bar plot with Sales Value as y-axis, Hierarchy Level 3 as x-axis, and Product category as hue
plt.figure(figsize=(15,10))
sns.barplot(data=sorted_data, x="Hierarchy Level 3", y="Sales Value", hue="Product category", palette="pastel", estimator=sum)

# Add labels for the total Sales Values above each bar
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), '${:.1f}M'.format(p.get_height()/1000000), 
            fontsize=10, color='black', ha='center', va='bottom')

# Format y-axis tick labels as millions
ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))

# Set axis labels and title
plt.xlabel("Hierarchy Level 3")
plt.ylabel("Sales Value (in millions)")
plt.title("Sum of Sales Values by Hierarchy Level 3 and Product Category")

plt.show()

# %%
plt.figure(figsize = (4,6))
grouped = adv_2022.groupby(['Hierarchy Level 3', 'Sales Value']).sum().reset_index()

plt.pie(grouped["Hierarchy Level 3"].value_counts(), labels = grouped["Hierarchy Level 3"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("CU level Percentage of sales")

plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

grouped_data = adv_2022.groupby(['Hierarchy Level 2', 'Product category'])['Sales Value'].sum().reset_index()
sorted_data = grouped_data.sort_values(['Hierarchy Level 2', 'Product category'], ascending=True)
# Define function to format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f"${x/1000000:.1f}M"

# Create the bar plot with Sales Value as y-axis, Hierarchy Level 3 as x-axis, and Product category as hue
plt.figure(figsize=(20,13))
sns.barplot(data=sorted_data, x="Hierarchy Level 2", y="Sales Value", hue="Product category", palette="pastel", estimator=sum, width=0.8)

# Add labels for the total Sales Values above each bar
##ax = plt.gca()
##for p in ax.patches:
##    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), '${:.1f}M'.format(p.get_height()/1000000), 
          ##  fontsize=10, color='black', ha='center', va='bottom')

# Format y-axis tick labels as millions
ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))

# Set axis labels and title
plt.xlabel("Hierarchy Level 2")
plt.ylabel("Sales Value (in millions)")
plt.title("Sum of Sales Values by Hierarchy Level 2 and Product Category")
plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize = (13,13))
grouped = adv_2022.groupby(['Hierarchy Level 2', 'Sales Value']).sum().reset_index()
sorted_data = grouped_data.sort_values('Hierarchy Level 2', ascending=True)

plt.pie(sorted_data["Hierarchy Level 2"].value_counts(), labels = grouped["Hierarchy Level 2"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("CA level Percentage of sales")

plt.show()

# %%
grouped
# Out:
#          Hierarchy Level 2  Sales Value
# 0                     Agra          0.0  \
# 1                     Agra         71.0
# 2                     Agra         98.0
# 3                     Agra        125.0
# 4                     Agra        135.0
# ...                    ...          ...
# 54290  West Up&Uttaranchal    1117325.0
# 54291  West Up&Uttaranchal    1255500.0
# 54292  West Up&Uttaranchal    1298935.0
# 54293  West Up&Uttaranchal    1487456.0
# 54294  West Up&Uttaranchal    1494450.0
#
#                                                    index
# 0      7357367377387397407417427437447457467471,0651,...  \
# 1                              14,78287,120113,06172,350
# 2                              123,07816,88672,33612,146
# 3                                         180,440113,089
# 4                                                136,375
# ...                                                  ...
# 54290                                              4,906
# 54291                                              4,919
# 54292                                              4,933
# 54293                                              4,816
# 54294                                              4,930
#
#                                             Advisor name
# 0      Abhishek kumarAbhishek kumarAbhishek kumarAbhi...  \
# 1       Arun kumarmayank sharmaPravesh Kumarkrishna kant
# 2      Ram Bahadur singhAshish Pathakkrishna kantAnki...
# 3                               Vivek KumarPravesh Kumar
# 4                                            Sahil kumar
# ...                                                  ...
# 54290                                      Akhilesh Garg
# 54291                                      Akhilesh Garg
# 54292                                      Akhilesh Garg
# 54293                                      Akhilesh Garg
# 54294                                      Akhilesh Garg
#
#                                            Retailer Name
# 0      SHARMA KHAD BEEJ BHANDARSHARMA KHAD BEEJ BHAND...  \
# 1      VISHAL TRADERSCHADDA TRADARSPRAKASH PESTICIDES...
# 2      KISAN AGRO & BEEJ BHANDARMAA BHGVATI BEEJ BHAN...
# 3                  BALAJI TRADERSShankar Trading Company
# 4                    Diksha Agro Agency Avm Beej Bhandar
# ...                                                  ...
# 54290                          PRAMOD TRADING CORPRATION
# 54291                          PRAMOD TRADING CORPRATION
# 54292                          PRAMOD TRADING CORPRATION
# 54293                            ABHISHEK GUPTA AND SONS
# 54294                          PRAMOD TRADING CORPRATION
#
#                                              Retailer ID
# 0      UP79115 INUP79115 INRJ72157 INUP79115 IN614220...  \
# 1               UP77800 INUP26597 INUP29584 INUP02320 IN
# 2               UP76274 INUP27451 INUP02320 IN6456013 IN
# 3                                   UP33364 IN6903647 IN
# 4                                             6346447 IN
# ...                                                  ...
# 54290                                         UP33737 IN
# 54291                                         UP33737 IN
# 54292                                         UP33737 IN
# 54293                                         UP34176 IN
# 54294                                         UP33737 IN
#
#                                               Advisor ID
# 0      185613 IN185613 IN185613 IN185613 IN185613 IN1...  \
# 1                   290933 IN285706 IN116359 IN492561 IN
# 2                   290931 IN403093 IN492561 IN640423 IN
# 3                                     290930 IN116359 IN
# 4                                              290929 IN
# ...                                                  ...
# 54290                                           44468 IN
# 54291                                           44468 IN
# 54292                                           44468 IN
# 54293                                           44468 IN
# 54294                                           44468 IN
#
#                       Month of Order Intent Created Date
# 0      JanuaryJanuaryJanuaryJanuaryJanuaryJanuaryJanu...  \
# 1                                  MayMayOctoberDecember
# 2                                 MayJulyOctoberDecember
# 3                                           MaySeptember
# 4                                                   July
# ...                                                  ...
# 54290                                             August
# 54291                                          September
# 54292                                           November
# 54293                                           February
# 54294                                            October
#
#        Advisor Phone Number
# 0            14258346046111  \
# 1               31151917105
# 2               35681170084
# 3               17497861237
# 4                7247881146
# ...                     ...
# 54290            9837029551
# 54291            9837029551
# 54292            9837029551
# 54293            9837029551
# 54294            9837029551
#
#                                            Country Code   ... Volume Intent
# 0      INININININININININININININININININININININININ...  ...     45655.275  \
# 1                                               ININININ  ...         0.300
# 2                                               ININININ  ...         0.400
# 3                                                   ININ  ...         0.200
# 4                                                     IN  ...         0.050
# ...                                                  ...  ...           ...
# 54290                                                 IN  ...         0.000
# 54291                                                 IN  ...       100.000
# 54292                                                 IN  ...      1690.000
# 54293                                                 IN  ...       150.900
# 54294                                                 IN  ...         0.000
#
#       Volume Cancelled Volume Purchased Returned Volume
# 0             1838.751          118.075            12.6  \
# 1                0.000            0.400             0.0
# 2                0.000            0.400             0.0
# 3                0.000            0.200             0.0
# 4                0.000            0.050             0.0
# ...                ...              ...             ...
# 54290            0.000          187.000             0.0
# 54291            0.000          310.000             0.0
# 54292            0.000         2299.000             0.0
# 54293            0.000          150.400             0.6
# 54294            0.000          369.000             0.0
#
#       Avg Volume Sold per Farmers Total Intent Value Cancelled Order Value
# 0                       57.980065       4.953762e+07             2232574.0  \
# 1                        0.400000       2.130000e+02                   0.0
# 2                        0.400000       3.920000e+02                   0.0
# 3                        0.200000       2.500000e+02                   0.0
# 4                        0.050000       1.350000e+02                   0.0
# ...                           ...                ...                   ...
# 54290                    1.027473       0.000000e+00                   0.0
# 54291                   34.444444       4.050000e+05                   0.0
# 54292                   40.333333       9.548500e+05                   0.0
# 54293                    0.101828       1.492401e+06                   0.0
# 54294                   46.125000       0.000000e+00                   0.0
#
#        Avg Sales per Farmer  Actual Commission  Intended Commission
# 0                  0.000000              622.0           996242.596
# 1                284.000000                7.2                5.400
# 2                392.000000                8.0                8.000
# 3                250.000000                6.0                6.000
# 4                135.000000                3.0                3.000
# ...                     ...                ...                  ...
# 54290           6139.148352            28050.0                0.000
# 54291         139500.000000            31620.0            10200.000
# 54292          22788.333333            32186.0            23660.000
# 54293           1003.004720            36096.0            36216.000
# 54294         186806.250000            37638.0                0.000
#
# [54295 rows x 35 columns]

# %%
sns.boxplot(y=adv_2022['Sales Value'])
plt.show()

# %%
sns.boxplot(x=adv_2022['Hierarchy Level 3'], y=adv_2022['Sales Value'])
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=adv_2021['Product category'], y=adv_2021['Sales Value'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 2
#       1 plt.figure(figsize = (10,7))
# ----> 2 sns.boxplot(x=adv_2021['Product category'], y=adv_2021['Sales Value'])
#       3 plt.show()
#
# NameError: name 'adv_2021' is not defined

# %%
from matplotlib.pyplot import figure
figure(figsize=(20, 10), dpi=80)
ax=sns.barplot(x='Product category',y='Sales Value', hue="Hierarchy Level 3" , data=adv_2022)

# %%
df_by_country=adv_2022.groupby(['Hierarchy Level 3','Product category'])['Sales Value'].sum().reset_index()
df_by_country
# Out:
#    Hierarchy Level 3 Product category   Sales Value
# 0            Central             Corn  2.434516e+07
# 1            Central       Fungicides  5.295935e+07
# 2            Central       Herbicides  3.973256e+07
# 3            Central     Insecticides  9.140811e+07
# 4            Central             Rice  1.066849e+07
# 5            Central       SeedGrowth  3.763216e+07
# 6               East             Corn  3.376037e+06
# 7               East       Fungicides  2.697543e+08
# 8               East       Herbicides  2.851160e+07
# 9               East     Insecticides  1.007177e+08
# 10              East             Rice  1.183831e+07
# 11              East       SeedGrowth  1.063962e+07
# 12             North             Corn  4.416210e+07
# 13             North       Fungicides  4.629718e+08
# 14             North       Herbicides  2.403348e+08
# 15             North     Insecticides  5.712855e+08
# 16             North             Rice  6.931500e+04
# 17             North       SeedGrowth  4.901634e+07
# 18             South             Corn  7.648174e+06
# 19             South       Fungicides  1.411627e+08
# 20             South       Herbicides  2.083559e+08
# 21             South     Insecticides  2.437557e+08
# 22             South             Rice  7.693500e+04
# 23             South       SeedGrowth  1.210629e+07
# 24              West             Corn  1.133829e+07
# 25              West       Fungicides  1.522606e+08
# 26              West       Herbicides  5.091673e+07
# 27              West     Insecticides  1.932327e+08
# 28              West             Rice  5.083790e+05
# 29              West       SeedGrowth  2.764865e+07

# %%
from matplotlib.pyplot import figure
figure(figsize=(20, 10), dpi=80)
ax=sns.barplot(x='Hierarchy Level 2',y='Sales Value', hue="Product category" , data=adv_2022)

# %%
corr=adv_2022.corr()
figure(figsize=(13, 10), dpi=80)
sns.heatmap(corr, cmap="coolwarm")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 corr=adv_2022.corr()
#       2 figure(figsize=(13, 10), dpi=80)
#       3 sns.heatmap(corr, cmap="coolwarm")
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '1,065'

# %%
adv_2022.corr()['Sales Value']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 adv_2022.corr()['Sales Value']
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '1,065'

# %%
adv_2022['Farmer Conversion'].corr(adv_2022['Active Retailers'])
# Out:
# 0.9990779811228794

# %%
adv_2022['Total Intent Value'].corr(adv_2022['Intended Commission'])
# Out:
# 0.9918160340795731

# %%
adv_2022['Distinct count of Farmers with multiple purchases'].corr(adv_2022['Farmers with multiple Intents'])
# Out:
# 0.9561716699851205

# %%
adv_2022['Total Order Intents'].corr(adv_2022['Farmers with Intent'])
# Out:
# 0.9933253950607983

# %%
results = adv_2022.groupby('Product category').sum().sort_values(by='Sales Value',ascending=True)
categories = results.index.tolist()
font1 = {'color':'#676767','size':11,'weight':'bold'}
font2 = {'color':'#919093','size':9,'weight':'bold'}

fig,ax = plt.subplots(figsize=(6,4))
bars = ax.barh(categories,results['Sales Value'],zorder=2,color='#CEB992')

ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)
ax.set_title('Sales by Category',fontdict = font, loc = 'left')
ax.set_ylabel('', fontdict = font2)
ax.tick_params(axis='x', labelsize=9)
ax.tick_params(axis='y', labelsize=9)
ax.set_facecolor('#F2F2F2')

plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x,_: '{:,.0f}M'.format(x/1000000)))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 10
#       7 bars = ax.barh(categories,results['Sales Value'],zorder=2,color='#CEB992')
#       9 ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)
# ---> 10 ax.set_title('Sales by Category',fontdict = font, loc = 'left')
#      11 ax.set_ylabel('', fontdict = font2)
#      12 ax.tick_params(axis='x', labelsize=9)
#
# NameError: name 'font' is not defined

# %%
# Create a pivot of HL3 and Product Type
resultspivot = adv_2022.groupby(["Hierarchy Level 3","Product category"]).sum()
pivot = resultspivot.groupby(["Hierarchy Level 3","Product category"])["Sales Value"].sum().unstack().fillna(0)
pivot = pivot.loc[pivot.sum(axis=1).sort_values(ascending=False).index]
pivot
# Out:
# Product category           Corn   Fungicides   Herbicides  Insecticides
# Hierarchy Level 3
# North              4.416210e+07  462971806.0  240334772.0   571285513.0  \
# South              7.648174e+06  141162664.0  208355877.0   243755704.0
# West               1.133829e+07  152260639.0   50916727.0   193232744.0
# East               3.376037e+06  269754252.0   28511596.0   100717657.0
# Central            2.434516e+07   52959347.0   39732558.0    91408106.0
#
# Product category         Rice  SeedGrowth
# Hierarchy Level 3
# North                 69315.0  49016339.0
# South                 76935.0  12106294.0
# West                 508379.0  27648653.0
# East               11838314.0  10639616.0
# Central            10668491.0  37632165.0

# %%
# Graph the pivot table
ax = pivot.plot.bar(stacked=True, color=['#5B867F','#84DCCF','#CEB234','#CEB992','#CEB552'], width=0.8, figsize=(8, 4), zorder=2)

font3 = {'color':'#474747','size':6,'weight':'bold'}

ax.set_facecolor('#F2F2F2')
ax.set_title("Product Sales by caregory", fontdict = font, loc='left')
ax.set_xlabel('', fontdict = font3)
ax.set_ylabel('', fontdict = font3)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.legend(prop={'size':8})
ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)

# Use FuncFormatter to add commas to x-axis labels
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: format(int(x), ',')))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 7
#       4 font3 = {'color':'#474747','size':6,'weight':'bold'}
#       6 ax.set_facecolor('#F2F2F2')
# ----> 7 ax.set_title("Product Sales by caregory", fontdict = font, loc='left')
#       8 ax.set_xlabel('', fontdict = font3)
#       9 ax.set_ylabel('', fontdict = font3)
#
# NameError: name 'font' is not defined

# %% [markdown]
# # What is the historical trend of sales?

# %%
ts=data.groupby(["date",'invoice_date'])["price"].sum().sort_index()
ts = ts.droplevel(level=0)
rolling_avg = ts.rolling(window=20).mean()
font5 = {'color':'#474747','size':10,'weight':'bold'}

ts.astype('float')
plt.figure(figsize=(15,8))
plt.gca().set_xlabel(None)
plt.title('Historical Sales', fontdict = font5, loc='left')

# Use FuncFormatter to add commas to x-axis labels
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: format(int(x), ',')))

plt.gca().set_facecolor('#F2F2F2')
plt.gca().grid(color='#CACACA', linestyle='--', linewidth=0.5)

ts.plot(label='Sales', color = '#6BA7DF', linewidth=2, zorder=2) 
rolling_avg.plot(label='20-Day Rolling Average', linewidth=2, color = '#FE9E00') 
plt.grid(True, color='#CACACA', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 ts=data.groupby(["date",'invoice_date'])["price"].sum().sort_index()
#       2 ts = ts.droplevel(level=0)
#       3 rolling_avg = ts.rolling(window=20).mean()
#
# NameError: name 'data' is not defined

# %% [markdown]
# # What is the distribution of sales by product type ?

# %%
What is the distribution of sales by product type and payment method?
# Create a pivot of Payment Type and Product Type
paymentpivot = data.groupby(["category","payment_method"]).sum()
paymentpivot2 = paymentpivot.groupby(["category","payment_method"])["price"].sum().unstack().fillna(0)
paymentpivot2 = paymentpivot2.loc[pivot.sum(axis=1).sort_values(ascending=False).index]
paymentpivot2
# Out:
# Object `method` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 get_ipython().run_line_magic('pinfo', 'method')
#       2 # Create a pivot of Payment Type and Product Type
# ----> 3 paymentpivot = data.groupby(["category","payment_method"]).sum()
#       4 paymentpivot2 = paymentpivot.groupby(["category","payment_method"])["price"].sum().unstack().fillna(0)
#       5 paymentpivot2 = paymentpivot2.loc[pivot.sum(axis=1).sort_values(ascending=False).index]
#
# NameError: name 'data' is not defined

# %%
# Graph the pivot table
ax = paymentpivot2.plot.bar(color=['#73937E','#CEB992','#585563'], width=0.7, figsize=(9, 5), zorder=2)


ax.set_facecolor('#F2F2F2')
ax.set_title("Sales by Product Type and Payment Method", fontdict = font, loc='left')
ax.set_xlabel('', fontdict = font3)
ax.set_ylabel('', fontdict = font3)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.legend(prop={'size':8})
ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)

# Use FuncFormatter to add commas to y-axis labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: format(int(x), ',')))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 # Graph the pivot table
# ----> 2 ax = paymentpivot2.plot.bar(color=['#73937E','#CEB992','#585563'], width=0.7, figsize=(9, 5), zorder=2)
#       5 ax.set_facecolor('#F2F2F2')
#       6 ax.set_title("Sales by Product Type and Payment Method", fontdict = font, loc='left')
#
# NameError: name 'paymentpivot2' is not defined

# %%
df['shopping_mall'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='The most visited shopping malls')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df['shopping_mall'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='The most visited shopping malls')
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
df['shopping_mall'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['shopping_mall'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['gender'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='Gender distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['gender'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='Gender distribution')
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
df['age'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df['age'].value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Distribution by

# %%
def age_group_(x):
    if x <= 20 :
        x= '18-20yo'
    elif x >20 and x <=30:
        x= '21-30yo'
    elif x >30 and x <=40:
        x= '31-40yo'
    elif x >40 and x <=50:
        x= '41-50yo'
    elif x >50 and x <=60:
        x= '51-60yo'
    else:
        x= '61yo+'
    return x

# %%
df['age_group']=df['age'].apply(age_group_)

# %%
df.groupby('age_group')['gender'].agg(['count'])

# %% [markdown]
# # Distribution of the average product price

# %%
df.groupby('category')['price'].agg(['mean','sum']).sort_values(by='mean',ascending=False)

# %%
fig = px.box(df, x='category', color='category', y='price', title='Distribution of the average product price', width=1200, height=600 ,template='plotly_dark')
fig.show()

# %%
plt.subplots(figsize=(18,10))
plt.xticks(rotation=90)
sns.stripplot(y='category', x='price', data=df, palette='Pastel1', s=15, marker='o', linewidth=1, alpha=0.1).set(title='Distribution of the average product price')
plt.show()

# %%
fig = px.histogram(df, x='age', y='price', color='shopping_mall',barmode='relative',marginal='box', title='Distribution of the price of goods in shopping centers and the costs of buyers', width=1200, height=600 ,template='plotly_dark')
fig.show()

# %%
df['price'] = df['price'].astype(int)

# %%
from sklearn import svm, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from matplotlib import style

# %% [markdown]
# # Distribution price by date

# %%
df['invoice_date']= pd.to_datetime(df['invoice_date'])

# %%
df.index = df.invoice_date

# %%
plt.figure(figsize=(20,10))
df.resample('M').customer_id.nunique().plot()
plt.show()

# %%
plt.figure(figsize=(18,10))
df.resample('D').customer_id.nunique().rolling(10).mean().plot()
plt.show()

# %%
plt.figure(figsize=(18,10))
df.resample('M').price.mean().plot()
plt.show()

# %%
fig = px.histogram(df, x='invoice_date', y='price', color='gender',barmode='relative',marginal='box', title='Distribution of the price of goods in shopping centers and the costs of buyers', width=1200, height=600 ,template='plotly_dark')
fig.show()

# %%
## We Will do Age Range Column To help us In Analysis
cut_labels_4 = ['10-20', '21-30', '31-50', '51-70']
cut_bins = [0,20, 30, 50, 71]
df["Age_Range"] =pd.cut(df.Age,
                            bins=cut_bins, 
                         labels=cut_labels_4)

# %%
#Average Total Payment For Both Genders
df.groupby('Gender')['Total_payment'].describe()

# %%
#The Correlation Age & Bill Price
df[['Age','Total_payment']].corr()

# %%
px.imshow(df[['Age','Total_payment']].corr(),text_auto=True , color_continuous_scale= 'redor')

# %%
#Average Price for each category
px.box(df , y= 'Price', color='Category')

# %%
#Performance of Malls across years
df5 =df.groupby(['MonthNo','Month','Shopping_mall','Year'])['Total_payment'].sum().reset_index()
df5

# %%
px.bar(df5 , x='Year' , y='Total_payment' , 
       color='Shopping_mall'
      ,barmode='group')
