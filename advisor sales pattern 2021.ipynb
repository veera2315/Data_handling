# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
adv_2021= pd.read_excel("C:/Users/EFRNV/Downloads/Advisor analasis Norman_req_India/India Advisor Details 2021.xlsx",'Sheet 1')
adv_2022= pd.read_excel("C:/Users/EFRNV/Downloads/Advisor analasis Norman_req_India/India Advisor Details 2022.xlsx")

# %%
adv_2021.head()
# Out:
#   index   Advisor name             Retailer Name Retailer ID Advisor ID
# 0   219  ADINARAYANA K                       NaN         NaN   98363 IN  \
# 1   221  ADINARAYANA K  KODANDA SRI RAMA MANURES  AP03117 IN   98363 IN
# 2   222  ADINARAYANA K  KODANDA SRI RAMA MANURES  AP03117 IN   98363 IN
# 3   223  ADINARAYANA K  KODANDA SRI RAMA MANURES  AP03117 IN   98363 IN
# 4   224  ADINARAYANA K  KODANDA SRI RAMA MANURES  AP03117 IN   98363 IN
#
#   Month of Order Intent Created Date  Advisor Phone Number Country Code
# 0                            January            8499901890            IN  \
# 1                            January            8499901890            IN
# 2                            January            8499901890            IN
# 3                            January            8499901890            IN
# 4                            January            8499901890            IN
#
#   Hierarchy Level 3 Hierarchy Level 2  ... Volume Cancelled Volume Purchased
# 0               NaN               NaN  ...              0.0              0.0  \
# 1               NaN               NaN  ...              0.0             12.8
# 2               NaN               NaN  ...              0.0             73.0
# 3               NaN               NaN  ...              0.0             10.0
# 4               NaN               NaN  ...              0.0             54.0
#
#   Returned Volume Avg Volume Sold per Farmers Total Intent Value
# 0             0.0                    0.000000            26210.0  \
# 1             0.0                    2.560000           186550.0
# 2             0.0                   24.333333            52100.0
# 3             0.0                    5.000000             5370.0
# 4             0.0                   27.000000           104900.0
#
#   Cancelled Order Value  Sales Value  Avg Sales per Farmer  Actual Commission
# 0                   0.0          0.0                   NaN               0.00  \
# 1                   0.0     183680.0          36736.000000           14918.40
# 2                   0.0      76066.0          25355.333333            2478.35
# 3                   0.0      10740.0           5370.000000             349.80
# 4                   0.0     113292.0          56646.000000            3766.50
#
#    Intended Commission
# 0                853.9
# 1              15151.5
# 2               1697.5
# 3                174.9
# 4               3487.5
#
# [5 rows x 35 columns]

# %%
adv_2021.describe()
# Out:
#        Advisor Phone Number  Total Order Intents
# count          6.844700e+04         68447.000000  \
# mean           8.844405e+09             3.329613
# std            1.013537e+09             9.817574
# min            1.231213e+09             1.000000
# 25%            8.101710e+09             1.000000
# 50%            9.130586e+09             1.000000
# 75%            9.642835e+09             3.000000
# max            9.998675e+09          1110.000000
#
#        Distinct count of Cancelled Order Intents  Farmers with Intent
# count                               68447.000000         68447.000000  \
# mean                                    0.108098             3.152775
# std                                     0.565356             9.330360
# min                                     0.000000             0.000000
# 25%                                     0.000000             1.000000
# 50%                                     0.000000             1.000000
# 75%                                     0.000000             3.000000
# max                                    21.000000          1108.000000
#
#        Farmers with multiple Intents  Farmers with Purchase
# count                   68447.000000           68447.000000  \
# mean                        1.240200               2.377898
# std                         2.605818               8.062319
# min                         0.000000               0.000000
# 25%                         0.000000               0.000000
# 50%                         1.000000               1.000000
# 75%                         1.000000               2.000000
# max                       154.000000             996.000000
#
#        Distinct count of Farmers with multiple purchases  Farmer Conversion
# count                                       68447.000000       68446.000000  \
# mean                                            1.413400           0.679593
# std                                             3.381003           0.465020
# min                                             0.000000           0.000000
# 25%                                             0.000000           0.000000
# 50%                                             1.000000           1.000000
# 75%                                             1.000000           1.000000
# max                                           267.000000           1.000000
#
#        Active Retailers  Volume Intent  Volume Cancelled  Volume Purchased
# count      68447.000000   60843.000000      68447.000000      68447.000000  \
# mean           0.682353      19.423880          1.016142         11.047349
# std            0.465565     161.239024         18.838958         77.306469
# min            0.000000       0.002000          0.000000          0.000000
# 25%            0.000000       0.750000          0.000000          0.000000
# 50%            1.000000       2.500000          0.000000          1.000000
# 75%            1.000000      10.000000          0.000000          5.000000
# max            1.000000   24500.000000       1700.000000       7344.000000
#
#        Returned Volume  Avg Volume Sold per Farmers  Total Intent Value
# count     68447.000000                 68447.000000        6.084300e+04  \
# mean          0.015849                     3.230618        3.163529e+04
# std           0.527717                    14.531658        1.549734e+05
# min           0.000000                     0.000000        3.200000e+01
# 25%           0.000000                     0.000000        2.250000e+03
# 50%           0.000000                     0.500000        7.224000e+03
# 75%           0.000000                     2.083333        2.292000e+04
# max          64.000000                  1000.000000        1.454274e+07
#
#        Cancelled Order Value   Sales Value  Avg Sales per Farmer
# count           6.844700e+04  6.844700e+04          46705.000000  \
# mean            1.096787e+03  2.049712e+04           8202.069420
# std             1.371906e+04  1.059252e+05          14138.330673
# min             0.000000e+00  0.000000e+00              0.000000
# 25%             0.000000e+00  0.000000e+00           1408.000000
# 50%             0.000000e+00  2.460000e+03           3778.500000
# 75%             0.000000e+00  1.352700e+04           9726.666667
# max             1.598220e+06  8.044920e+06         936650.000000
#
#        Actual Commission  Intended Commission
# count       68447.000000         67666.000000
# mean          521.575457           719.227932
# std          2687.220257          3711.839611
# min             0.000000             0.000000
# 25%             0.000000            32.000000
# 50%            60.000000           144.000000
# 75%           337.410000           504.000000
# max        202176.000000        365472.000000

# %%
adv_2021.nunique()
# Out:
# index                                                68447
# Advisor name                                          1789
# Retailer Name                                         2327
# Retailer ID                                           2381
# Advisor ID                                            1842
# Month of Order Intent Created Date                      12
# Advisor Phone Number                                  1842
# Country Code                                             1
# Hierarchy Level 3                                        5
# Hierarchy Level 2                                       48
# Hierarchy Level 1                                      240
# Advisor Type                                            16
# Product category                                         7
# Product Brand                                           39
# Product Name                                           184
# Unit                                                     3
# Total Order Intents                                    139
# Distinct count of Cancelled Order Intents               21
# Farmers with Intent                                    132
# Farmers with multiple Intents                           62
# Farmers with Purchase                                  126
# Distinct count of Farmers with multiple purchases       72
# Farmer Conversion                                       83
# Active Retailers                                         2
# Volume Intent                                         2187
# Volume Cancelled                                       394
# Volume Purchased                                      1996
# Returned Volume                                         79
# Avg Volume Sold per Farmers                           3839
# Total Intent Value                                    7836
# Cancelled Order Value                                 1699
# Sales Value                                           6924
# Avg Sales per Farmer                                 10671
# Actual Commission                                     4500
# Intended Commission                                   4710
# dtype: int64

# %%
adv_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 68447 entries, 0 to 68446
# Data columns (total 35 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   index                                              68447 non-null  object
#  1   Advisor name                                       68447 non-null  object
#  2   Retailer Name                                      47304 non-null  object
#  3   Retailer ID                                        47304 non-null  object
#  4   Advisor ID                                         68447 non-null  object
#  5   Month of Order Intent Created Date                 68447 non-null  object
#  6   Advisor Phone Number                               68447 non-null  int64
#  7   Country Code                                       68447 non-null  object
#  8   Hierarchy Level 3                                  62853 non-null  object
#  9   Hierarchy Level 2                                  62853 non-null  object
#  10  Hierarchy Level 1                                  62853 non-null  object
#  11  Advisor Type                                       68447 non-null  object
#  12  Product category                                   68447 non-null  object
#  13  Product Brand                                      68447 non-null  object
#  14  Product Name                                       68447 non-null  object
#  15  Unit                                               68447 non-null  object
#  16  Total Order Intents                                68447 non-null  int64
#  17  Distinct count of Cancelled Order Intents          68447 non-null  int64
#  18  Farmers with Intent                                68447 non-null  int64
#  19  Farmers with multiple Intents                      68447 non-null  int64
#  20  Farmers with Purchase                              68447 non-null  int64
#  21  Distinct count of Farmers with multiple purchases  68447 non-null  int64
#  22  Farmer Conversion                                  68446 non-null  float64
#  23  Active Retailers                                   68447 non-null  int64
#  24  Volume Intent                                      60843 non-null  float64
#  25  Volume Cancelled                                   68447 non-null  float64
#  26  Volume Purchased                                   68447 non-null  float64
#  27  Returned Volume                                    68447 non-null  float64
#  28  Avg Volume Sold per Farmers                        68447 non-null  float64
#  29  Total Intent Value                                 60843 non-null  float64
#  30  Cancelled Order Value                              68447 non-null  float64
#  31  Sales Value                                        68447 non-null  float64
#  32  Avg Sales per Farmer                               46705 non-null  float64
#  33  Actual Commission                                  68447 non-null  float64
#  34  Intended Commission                                67666 non-null  float64
# dtypes: float64(12), int64(8), object(15)
# memory usage: 18.3+ MB

# %%
print("Is there any missing data?")
print(adv_2021.isna().sum())
# Out:
# Is there any missing data?
# index                                                    0
# Advisor name                                             0
# Retailer Name                                        21143
# Retailer ID                                          21143
# Advisor ID                                               0
# Month of Order Intent Created Date                       0
# Advisor Phone Number                                     0
# Country Code                                             0
# Hierarchy Level 3                                     5594
# Hierarchy Level 2                                     5594
# Hierarchy Level 1                                     5594
# Advisor Type                                             0
# Product category                                         0
# Product Brand                                            0
# Product Name                                             0
# Unit                                                     0
# Total Order Intents                                      0
# Distinct count of Cancelled Order Intents                0
# Farmers with Intent                                      0
# Farmers with multiple Intents                            0
# Farmers with Purchase                                    0
# Distinct count of Farmers with multiple purchases        0
# Farmer Conversion                                        1
# Active Retailers                                         0
# Volume Intent                                         7604
# Volume Cancelled                                         0
# Volume Purchased                                         0
# Returned Volume                                          0
# Avg Volume Sold per Farmers                              0
# Total Intent Value                                    7604
# Cancelled Order Value                                    0
# Sales Value                                              0
# Avg Sales per Farmer                                 21742
# Actual Commission                                        0
# Intended Commission                                    781
# dtype: int64

# %%
# Group the data frame by 'month' and 'category' and sum the 'sales' column:

#grouped = adv_2021.groupby(['Month of Order Intent Created Date', 'Product category','Product Brand','Product Name']).sum().reset_index()
#grouped = adv_2021.groupby(['Month of Order Intent Created Date', 'Product category','Product Brand']).sum().reset_index()
grouped = adv_2021.groupby(['Month of Order Intent Created Date', 'Product category']).sum().reset_index()

# %%
# Use pivot() function to create a pivot table with 'month' as the index and 'category' as the columns:

#pivot_table = grouped.pivot(index='Month of Order Intent Created Date', columns=['Product category','Product Brand','Product Name'], values='Sales Value')
#pivot_table = grouped.pivot(index='Month of Order Intent Created Date', columns=['Product category','Product Brand'], values='Sales Value')
pivot_table = grouped.pivot(index='Month of Order Intent Created Date', columns='Product category', values='Sales Value')

# %%
# Define your pivot table first
pivot_table = pd.pivot_table(grouped, values='Sales Value', index='Month of Order Intent Created Date', columns='Product category', aggfunc=sum)
# Convert index to DateTimeIndex
#pivot_table.index = pd.to_datetime(pivot_table.index)

# Sort index in ascending order
pivot_table = pivot_table.sort_index()

# Calculate sales values and sales values in millions
sales_values = pivot_table.sum(axis=1)
sales_values_millions = [value / 1000000 for value in sales_values]

# Plot the pivot table and add labels
#plt.figure(figsize=(30, 20)) # Set the figure size here
fig, ax = plt.subplots(figsize=(15, 10))
pivot_table.plot(kind='line', ax=ax)
ax.set_xlabel('Month of Order Intent Created Date')
ax.set_ylabel('Sales Value')
ax.set_title('Sales patterns by Product category')
plt.xticks(rotation=90)

# Add labels to the plot
for i, value in enumerate(sales_values_millions):
    ax.text(i, sales_values[i]+0.005*max(sales_values), f'{value:.2f}M', ha='center', va='bottom')

# Set y-axis limits
ax.set_ylim([0, max(sales_values)*1.1])

plt.show()

# %%
plt.figure(figsize = (4,6))
grouped = adv_2021.groupby(['Product category', 'Sales Value']).sum().reset_index()

plt.pie(grouped["Product category"].value_counts(), labels = grouped["Product category"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("category Percentage")

plt.show()

# %%
plt.figure(figsize = (6,6))
grouped = adv_2021.groupby(['Month of Order Intent Created Date', 'Sales Value']).sum().reset_index()
#grouped = groupede.sort_values(by='Month of Order Intent Created Date')

plt.pie(grouped["Month of Order Intent Created Date"].value_counts(), labels = grouped["Month of Order Intent Created Date"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("Monthly sales Percentage")

plt.show()

# %%
grouped = adv_2021.groupby(['Month of Order Intent Created Date', 'Product category']).sum().reset_index()

# Define your pivot table first
pivot_table = pd.pivot_table(grouped, values='Sales Value', index='Product category', columns='Month of Order Intent Created Date', aggfunc=sum)
# Convert index to DateTimeIndex
#pivot_table.index = pd.to_datetime(pivot_table.index)

# Sort index in ascending order
pivot_table = pivot_table.sort_index()

# Calculate sales values and sales values in millions
sales_values = pivot_table.sum(axis=1)
sales_values_millions = [value / 1000000 for value in sales_values]

# Plot the pivot table and add labels
#plt.figure(figsize=(30, 20)) # Set the figure size here
fig, ax = plt.subplots(figsize=(15, 10))
pivot_table.plot(kind='line', ax=ax)
ax.set_xlabel('Product category')
ax.set_ylabel('Sales Value')
ax.set_title('Sales patterns by month')
#plt.xticks(rotation=90)

# Add labels to the plot
for i, value in enumerate(sales_values_millions):
    ax.text(i, sales_values[i]+0.005*max(sales_values), f'{value:.2f}M', ha='center', va='bottom')

# Set y-axis limits
ax.set_ylim([0, max(sales_values)*1.1])

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# group the data by the values in column1 and column2, and sum the values in column3
grouped_data = adv_2021.groupby(['Hierarchy Level 3', 'Product category'])['Sales Value'].sum()

# convert the grouped data to a dataframe
grouped_data_df = grouped_data.reset_index()

# extract column1, column2, and sales_value from the dataframe
column1 = grouped_data_df['Hierarchy Level 3']
column2 = grouped_data_df['Product category']
sales_value = grouped_data_df['Sales Value']

# create a figure and axis objects
fig, ax = plt.subplots(figsize=(10, 10))

# plot sales_value against column1 and column2
ax.scatter(column1, column2, s=sales_value*10, alpha=0.5, c=sales_value, cmap='viridis')

# add text labels for the sales value sums
for i, txt in enumerate(sales_value):
    ax.text(column1[i], column2[i], f'{txt/1000000:.2f}M', ha='center', va='center', color='red')

# set x and y axis labels
ax.set_xlabel('Hierarchy Level 3')
ax.set_ylabel('Product category')

# display the plot
plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

grouped_data = adv_2021.groupby(['Hierarchy Level 3', 'Product category'])['Sales Value'].sum().reset_index()
sorted_data = grouped_data.sort_values(['Hierarchy Level 3', 'Product category'], ascending=True)

# Define function to format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f"${x/1000000:.1f}M"

# Create the bar plot with Sales Value as y-axis, Hierarchy Level 3 as x-axis, and Product category as hue
plt.figure(figsize=(15,10))
sns.barplot(data=sorted_data, x="Hierarchy Level 3", y="Sales Value", hue="Product category", palette="pastel", estimator=sum)

# Add labels for the total Sales Values above each bar
ax = plt.gca()
for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), '${:.1f}M'.format(p.get_height()/1000000), 
            fontsize=10, color='black', ha='center', va='bottom')

# Format y-axis tick labels as millions
ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))

# Set axis labels and title
plt.xlabel("Hierarchy Level 3")
plt.ylabel("Sales Value (in millions)")
plt.title("Sum of Sales Values by Hierarchy Level 3 and Product Category")

plt.show()

# %%
plt.figure(figsize = (4,6))
grouped = adv_2021.groupby(['Hierarchy Level 3', 'Sales Value']).sum().reset_index()

plt.pie(grouped["Hierarchy Level 3"].value_counts(), labels = grouped["Hierarchy Level 3"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("CU level Percentage of sales")

plt.show()

# %%
# Import necessary libraries
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

grouped_data = adv_2021.groupby(['Hierarchy Level 2', 'Product category'])['Sales Value'].sum().reset_index()
sorted_data = grouped_data.sort_values(['Hierarchy Level 2', 'Product category'], ascending=True)
# Define function to format y-axis tick labels as millions
def millions_formatter(x, pos):
    return f"${x/1000000:.1f}M"

# Create the bar plot with Sales Value as y-axis, Hierarchy Level 3 as x-axis, and Product category as hue
plt.figure(figsize=(20,13))
sns.barplot(data=sorted_data, x="Hierarchy Level 2", y="Sales Value", hue="Product category", palette="pastel", estimator=sum, width=0.8)

# Add labels for the total Sales Values above each bar
##ax = plt.gca()
##for p in ax.patches:
##    ax.text(p.get_x() + p.get_width() / 2., p.get_height(), '${:.1f}M'.format(p.get_height()/1000000), 
          ##  fontsize=10, color='black', ha='center', va='bottom')

# Format y-axis tick labels as millions
ax.yaxis.set_major_formatter(ticker.FuncFormatter(millions_formatter))

# Set axis labels and title
plt.xlabel("Hierarchy Level 2")
plt.ylabel("Sales Value (in millions)")
plt.title("Sum of Sales Values by Hierarchy Level 2 and Product Category")
plt.xticks(rotation=90)

plt.show()

# %%
plt.figure(figsize = (13,13))
grouped = adv_2021.groupby(['Hierarchy Level 2', 'Sales Value']).sum().reset_index()
sorted_data = grouped_data.sort_values('Hierarchy Level 2', ascending=True)

plt.pie(sorted_data["Hierarchy Level 2"].value_counts(), labels = grouped["Hierarchy Level 2"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("CA level Percentage of sales")

plt.show()

# %%
grouped
# Out:
#          Hierarchy Level 2  Sales Value
# 0                     Agra          0.0  \
# 1                     Agra        119.0
# 2                     Agra        135.0
# 3                     Agra        154.0
# 4                     Agra        166.0
# ...                    ...          ...
# 23467  West Up&Uttaranchal     672128.0
# 23468  West Up&Uttaranchal     703238.0
# 23469  West Up&Uttaranchal     744900.0
# 23470  West Up&Uttaranchal    1046528.0
# 23471  West Up&Uttaranchal    1226160.0
#
#                                                    index
# 0      4,0554,0565,7095,7105,7115,71213,13733,81133,8...  \
# 1                                                 66,973
# 2                                                    186
# 3                                                 13,217
# 4                                                    130
# ...                                                  ...
# 23467                                              1,251
# 23468                                             41,616
# 23469                                              1,234
# 23470                                              1,256
# 23471                                              1,255
#
#                                             Advisor name
# 0      Ankit kumarAnkit kumarAshwani kumarAshwani kum...  \
# 1                                            Vinod kumar
# 2                                          Abneesh kumar
# 3                                        Dharmveer Singh
# 4                                         Abhishek kumar
# ...                                                  ...
# 23467                                      Akhilesh Garg
# 23468                                Pawan kumar kaushik
# 23469                                      Akhilesh Garg
# 23470                                      Akhilesh Garg
# 23471                                      Akhilesh Garg
#
#                                            Retailer Name
# 0      CHOLA BEEJ BHANDARKALKA TRADERSKALKA TRADERSKA...  \
# 1                                         YOGESH TRADERS
# 2                                         Dhenki Traders
# 3                            TILAK KRISHI RAKHHA KENDARA
# 4                                BRAHMA NAND ASHOK KUMAR
# ...                                                  ...
# 23467                            ABHISHEK GUPTA AND SONS
# 23468                                     YOGESH TRADERS
# 23469                            ABHISHEK GUPTA AND SONS
# 23470                            ABHISHEK GUPTA AND SONS
# 23471                            ABHISHEK GUPTA AND SONS
#
#                                              Retailer ID
# 0      UP77736 INUP03500 INUP03500 INUP03500 INUP7773...  \
# 1                                             UP27402 IN
# 2                                             WB00760 IN
# 3                                             UP26540 IN
# 4                                             UP20952 IN
# ...                                                  ...
# 23467                                         UP34176 IN
# 23468                                         UP27402 IN
# 23469                                         UP34176 IN
# 23470                                         UP34176 IN
# 23471                                         UP34176 IN
#
#                                               Advisor ID
# 0      105294 IN105294 IN42153 IN42153 IN42153 IN4215...  \
# 1                                               57928 IN
# 2                                              183497 IN
# 3                                              157503 IN
# 4                                              185613 IN
# ...                                                  ...
# 23467                                           44468 IN
# 23468                                           43334 IN
# 23469                                           44468 IN
# 23470                                           44468 IN
# 23471                                           44468 IN
#
#                       Month of Order Intent Created Date
# 0      JanuaryJanuaryJanuaryJanuaryJanuaryJanuaryJanu...  \
# 1                                              September
# 2                                               November
# 3                                                October
# 4                                               November
# ...                                                  ...
# 23467                                          September
# 23468                                               July
# 23469                                             August
# 23470                                          September
# 23471                                          September
#
#        Advisor Phone Number
# 0             5243116838408  \
# 1                8650362845
# 2                9568863164
# 3                7505898213
# 4                7247822845
# ...                     ...
# 23467            9837029551
# 23468            9634066696
# 23469            9837029551
# 23470            9837029551
# 23471            9837029551
#
#                                            Country Code   ... Volume Intent
# 0      INININININININININININININININININININININININ...  ...    18309.5245  \
# 1                                                     IN  ...        0.0000
# 2                                                     IN  ...        0.0000
# 3                                                     IN  ...        0.0400
# 4                                                     IN  ...        0.0000
# ...                                                  ...  ...           ...
# 23467                                                 IN  ...       52.0000
# 23468                                                 IN  ...      169.5000
# 23469                                                 IN  ...      130.0000
# 23470                                                 IN  ...       79.0000
# 23471                                                 IN  ...       58.0000
#
#       Volume Cancelled Volume Purchased Returned Volume
# 0              905.359             0.00             0.0  \
# 1                0.000             0.10             0.0
# 2                0.000             0.05             0.0
# 3                0.000             0.01             0.0
# 4                0.000             1.00             0.0
# ...                ...              ...             ...
# 23467            0.000           284.80             0.0
# 23468            0.000           120.50             0.0
# 23469            0.000           130.00             0.0
# 23470            0.000           233.60             0.0
# 23471            0.000           312.00             0.0
#
#       Avg Volume Sold per Farmers Total Intent Value Cancelled Order Value
# 0                        0.000000       2.048780e+07          1.204685e+06  \
# 1                        0.100000       0.000000e+00          0.000000e+00
# 2                        0.050000       0.000000e+00          0.000000e+00
# 3                        0.010000       6.160000e+02          0.000000e+00
# 4                        1.000000       0.000000e+00          0.000000e+00
# ...                           ...                ...                   ...
# 23467                    6.780952       1.227200e+05          0.000000e+00
# 23468                   20.083333       9.892020e+05          0.000000e+00
# 23469                   32.500000       7.449000e+05          0.000000e+00
# 23470                    5.840000       3.539200e+05          0.000000e+00
# 23471                   18.352941       2.279400e+05          0.000000e+00
#
#        Avg Sales per Farmer  Actual Commission  Intended Commission
# 0                  0.000000             0.0000           503253.852
# 1                119.000000             2.9988                0.000
# 2                135.000000             3.0000                0.000
# 3                154.000000             3.0000               12.000
# 4                166.000000             4.0000                0.000
# ...                     ...                ...                  ...
# 23467          16003.047619         14240.0000             2600.000
# 23468         117206.333333         17593.0000            24747.000
# 23469         186225.000000         18720.0000            18720.000
# 23470          26163.200000         25696.0000             8690.000
# 23471          72127.058824         30899.2320             5744.088
#
# [23472 rows x 35 columns]

# %%
sns.boxplot(y=adv_2021['Sales Value'])
plt.show()

# %%
sns.boxplot(x=adv_2021['Hierarchy Level 3'], y=adv_2021['Sales Value'])
plt.show()

# %%
plt.figure(figsize = (10,7))
sns.boxplot(x=adv_2021['Product category'], y=adv_2021['Sales Value'])
plt.show()

# %%
from matplotlib.pyplot import figure
figure(figsize=(20, 10), dpi=80)
ax=sns.barplot(x='Product category',y='Sales Value', hue="Hierarchy Level 3" , data=adv_2021)

# %%
df_by_country=adv_2021.groupby(['Hierarchy Level 3','Product category'])['Sales Value'].sum().reset_index()
df_by_country
# Out:
#    Hierarchy Level 3 Product category   Sales Value
# 0            Central             Corn  5.837665e+05
# 1            Central       Fungicides  3.523399e+07
# 2            Central       Herbicides  1.414563e+07
# 3            Central     Insecticides  2.766340e+07
# 4            Central             Rice  5.840293e+06
# 5            Central       SeedGrowth  2.076251e+07
# 6               East             Corn  1.106469e+06
# 7               East       Fungicides  2.421443e+08
# 8               East       Herbicides  5.828519e+06
# 9               East     Insecticides  5.035678e+07
# 10              East             Rice  1.159090e+07
# 11              East       SeedGrowth  3.593356e+06
# 12             North             Corn  4.176057e+05
# 13             North           Cotton  1.043900e+06
# 14             North       Fungicides  1.706145e+08
# 15             North       Herbicides  2.265669e+07
# 16             North     Insecticides  1.921155e+08
# 17             North             Rice  4.940000e+04
# 18             North       SeedGrowth  2.566262e+07
# 19             South             Corn  1.979573e+06
# 20             South           Cotton  0.000000e+00
# 21             South       Fungicides  1.093680e+08
# 22             South       Herbicides  2.901526e+07
# 23             South     Insecticides  1.215923e+08
# 24             South             Rice  1.786000e+03
# 25             South       SeedGrowth  4.735062e+06
# 26              West             Corn  2.481651e+06
# 27              West           Cotton  7.056400e+04
# 28              West       Fungicides  7.868651e+07
# 29              West       Herbicides  1.117324e+07
# 30              West     Insecticides  8.854512e+07
# 31              West             Rice  5.948000e+04
# 32              West       SeedGrowth  9.841363e+06

# %%
from matplotlib.pyplot import figure
figure(figsize=(20, 10), dpi=80)
ax=sns.barplot(x='Hierarchy Level 2',y='Sales Value', hue="Product category" , data=adv_2021)

# %%
corr=adv_2021.corr()
figure(figsize=(13, 10), dpi=80)
sns.heatmap(corr, cmap="coolwarm")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 corr=adv_2021.corr()
#       2 figure(figsize=(13, 10), dpi=80)
#       3 sns.heatmap(corr, cmap="coolwarm")
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '1,632'

# %%
adv_2021.corr()['Sales Value']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 adv_2021.corr()['Sales Value']
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File c:\Users\EFRNV\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '1,632'

# %%
adv_2021['Farmer Conversion'].corr(adv_2021['Active Retailers'])
# Out:
# 0.9970991733127776

# %%
adv_2021['Total Intent Value'].corr(adv_2021['Intended Commission'])
# Out:
# 0.9932891149434216

# %%
adv_2021['Distinct count of Farmers with multiple purchases'].corr(adv_2021['Farmers with multiple Intents'])
# Out:
# 0.8242721223620991

# %%
adv_2021['Total Order Intents'].corr(adv_2021['Farmers with Intent'])
# Out:
# 0.975272237987058

# %%
results = adv_2021.groupby('Product category').sum().sort_values(by='Sales Value',ascending=True)
categories = results.index.tolist()
font1 = {'color':'#676767','size':11,'weight':'bold'}
font2 = {'color':'#919093','size':9,'weight':'bold'}

fig,ax = plt.subplots(figsize=(6,4))
bars = ax.barh(categories,results['Sales Value'],zorder=2,color='#CEB992')

ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)
ax.set_title('Sales by Category',fontdict = font, loc = 'left')
ax.set_ylabel('', fontdict = font2)
ax.tick_params(axis='x', labelsize=9)
ax.tick_params(axis='y', labelsize=9)
ax.set_facecolor('#F2F2F2')

plt.gca().xaxis.set_major_formatter(FuncFormatter(lambda x,_: '{:,.0f}M'.format(x/1000000)))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 10
#       7 bars = ax.barh(categories,results['Sales Value'],zorder=2,color='#CEB992')
#       9 ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)
# ---> 10 ax.set_title('Sales by Category',fontdict = font, loc = 'left')
#      11 ax.set_ylabel('', fontdict = font2)
#      12 ax.tick_params(axis='x', labelsize=9)
#
# NameError: name 'font' is not defined

# %%
# Create a pivot of Gender and Product Type
resultspivot = adv_2021.groupby(["Hierarchy Level 3","Product category"]).sum()
pivot = resultspivot.groupby(["Hierarchy Level 3","Product category"])["Sales Value"].sum().unstack().fillna(0)
pivot = pivot.loc[pivot.sum(axis=1).sort_values(ascending=False).index]
pivot
# Out:
# Product category           Corn     Cotton   Fungicides  Herbicides
# Hierarchy Level 3
# North              4.176057e+05  1043900.0  170614453.0  22656687.0  \
# East               1.106469e+06        0.0  242144329.0   5828519.0
# South              1.979573e+06        0.0  109368050.0  29015259.0
# West               2.481651e+06    70564.0   78686514.0  11173241.0
# Central            5.837665e+05        0.0   35233993.0  14145632.0
#
# Product category   Insecticides        Rice  SeedGrowth
# Hierarchy Level 3
# North               192115453.0     49400.0  25662624.0
# East                 50356783.0  11590899.0   3593356.0
# South               121592283.0      1786.0   4735062.0
# West                 88545123.0     59480.0   9841363.0
# Central              27663399.0   5840293.0  20762507.0

# %%
# Graph the pivot table
ax = pivot.plot.bar(stacked=True, color=['#5B867F','#84DCCF','#CEB234','#CEB992','#CEB552'], width=0.8, figsize=(8, 4), zorder=2)

font3 = {'color':'#474747','size':6,'weight':'bold'}

ax.set_facecolor('#F2F2F2')
ax.set_title("Product Sales by caregory", fontdict = font, loc='left')
ax.set_xlabel('', fontdict = font3)
ax.set_ylabel('', fontdict = font3)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.legend(prop={'size':8})
ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)

# Use FuncFormatter to add commas to x-axis labels
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: format(int(x), ',')))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 7
#       4 font3 = {'color':'#474747','size':6,'weight':'bold'}
#       6 ax.set_facecolor('#F2F2F2')
# ----> 7 ax.set_title("Product Sales by caregory", fontdict = font, loc='left')
#       8 ax.set_xlabel('', fontdict = font3)
#       9 ax.set_ylabel('', fontdict = font3)
#
# NameError: name 'font' is not defined

# %% [markdown]
# # What is the historical trend of sales?

# %%
ts=data.groupby(["date",'invoice_date'])["price"].sum().sort_index()
ts = ts.droplevel(level=0)
rolling_avg = ts.rolling(window=20).mean()
font5 = {'color':'#474747','size':10,'weight':'bold'}

ts.astype('float')
plt.figure(figsize=(15,8))
plt.gca().set_xlabel(None)
plt.title('Historical Sales', fontdict = font5, loc='left')

# Use FuncFormatter to add commas to x-axis labels
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda x, _: format(int(x), ',')))

plt.gca().set_facecolor('#F2F2F2')
plt.gca().grid(color='#CACACA', linestyle='--', linewidth=0.5)

ts.plot(label='Sales', color = '#6BA7DF', linewidth=2, zorder=2) 
rolling_avg.plot(label='20-Day Rolling Average', linewidth=2, color = '#FE9E00') 
plt.grid(True, color='#CACACA', linestyle='--', linewidth=0.5)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 ts=data.groupby(["date",'invoice_date'])["price"].sum().sort_index()
#       2 ts = ts.droplevel(level=0)
#       3 rolling_avg = ts.rolling(window=20).mean()
#
# NameError: name 'data' is not defined

# %% [markdown]
# # What is the distribution of sales by product type?

# %%
What is the distribution of sales by product type and payment method?
# Create a pivot of Payment Type and Product Type
paymentpivot = data.groupby(["category","payment_method"]).sum()
paymentpivot2 = paymentpivot.groupby(["category","payment_method"])["price"].sum().unstack().fillna(0)
paymentpivot2 = paymentpivot2.loc[pivot.sum(axis=1).sort_values(ascending=False).index]
paymentpivot2
# Out:
# Object `method` not found.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 3
#       1 get_ipython().run_line_magic('pinfo', 'method')
#       2 # Create a pivot of Payment Type and Product Type
# ----> 3 paymentpivot = data.groupby(["category","payment_method"]).sum()
#       4 paymentpivot2 = paymentpivot.groupby(["category","payment_method"])["price"].sum().unstack().fillna(0)
#       5 paymentpivot2 = paymentpivot2.loc[pivot.sum(axis=1).sort_values(ascending=False).index]
#
# NameError: name 'data' is not defined

# %%
# Graph the pivot table
ax = pivot.plot.bar(stacked=True, color=['#5B867F','#84DCCF','#CEB234','#CEB992','#CEB552'], width=0.8, figsize=(8, 4), zorder=2)


ax.set_facecolor('#F2F2F2')
ax.set_title("Sales by Product Type and Payment Method", fontdict = font, loc='left')
ax.set_xlabel('', fontdict = font3)
ax.set_ylabel('', fontdict = font3)
ax.tick_params(axis='x', labelsize=8)
ax.tick_params(axis='y', labelsize=8)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
ax.legend(prop={'size':8})
ax.grid(color='#CACACA', linestyle='--', linewidth=0.5)

# Use FuncFormatter to add commas to y-axis labels
ax.yaxis.set_major_formatter(FuncFormatter(lambda x, _: format(int(x), ',')))

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 6
#       2 ax = pivot.plot.bar(stacked=True, color=['#5B867F','#84DCCF','#CEB234','#CEB992','#CEB552'], width=0.8, figsize=(8, 4), zorder=2)
#       5 ax.set_facecolor('#F2F2F2')
# ----> 6 ax.set_title("Sales by Product Type and Payment Method", fontdict = font, loc='left')
#       7 ax.set_xlabel('', fontdict = font3)
#       8 ax.set_ylabel('', fontdict = font3)
#
# NameError: name 'font' is not defined

# %%
df['shopping_mall'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='The most visited shopping malls')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df['shopping_mall'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='The most visited shopping malls')
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
df['shopping_mall'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df['shopping_mall'].value_counts()
#
# NameError: name 'df' is not defined

# %%
df['gender'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='Gender distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 df['gender'].value_counts().plot(kind='pie', subplots=True, autopct='%1.2f', figsize=(8,8), title='Gender distribution')
#       2 plt.show()
#
# NameError: name 'df' is not defined

# %%
df['age'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 df['age'].value_counts()
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Distribution by

# %%
def age_group_(x):
    if x <= 20 :
        x= '18-20yo'
    elif x >20 and x <=30:
        x= '21-30yo'
    elif x >30 and x <=40:
        x= '31-40yo'
    elif x >40 and x <=50:
        x= '41-50yo'
    elif x >50 and x <=60:
        x= '51-60yo'
    else:
        x= '61yo+'
    return x

# %%
df['age_group']=df['age'].apply(age_group_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 df['age_group']=df['age'].apply(age_group_)
#
# NameError: name 'df' is not defined

# %%
df.groupby('age_group')['gender'].agg(['count'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 df.groupby('age_group')['gender'].agg(['count'])
#
# NameError: name 'df' is not defined

# %% [markdown]
# # Distribution of the average product price

# %%
df.groupby('category')['price'].agg(['mean','sum']).sort_values(by='mean',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.groupby('category')['price'].agg(['mean','sum']).sort_values(by='mean',ascending=False)
#
# NameError: name 'df' is not defined

# %%
fig = px.box(df, x='category', color='category', y='price', title='Distribution of the average product price', width=1200, height=600 ,template='plotly_dark')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 fig = px.box(df, x='category', color='category', y='price', title='Distribution of the average product price', width=1200, height=600 ,template='plotly_dark')
#       2 fig.show()
#
# NameError: name 'px' is not defined

# %%
plt.subplots(figsize=(18,10))
plt.xticks(rotation=90)
sns.stripplot(y='category', x='price', data=df, palette='Pastel1', s=15, marker='o', linewidth=1, alpha=0.1).set(title='Distribution of the average product price')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 3
#       1 plt.subplots(figsize=(18,10))
#       2 plt.xticks(rotation=90)
# ----> 3 sns.stripplot(y='category', x='price', data=df, palette='Pastel1', s=15, marker='o', linewidth=1, alpha=0.1).set(title='Distribution of the average product price')
#       4 plt.show()
#
# NameError: name 'df' is not defined

# %%
fig = px.histogram(df, x='age', y='price', color='shopping_mall',barmode='relative',marginal='box', title='Distribution of the price of goods in shopping centers and the costs of buyers', width=1200, height=600 ,template='plotly_dark')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 fig = px.histogram(df, x='age', y='price', color='shopping_mall',barmode='relative',marginal='box', title='Distribution of the price of goods in shopping centers and the costs of buyers', width=1200, height=600 ,template='plotly_dark')
#       2 fig.show()
#
# NameError: name 'px' is not defined

# %%
df['price'] = df['price'].astype(int)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df['price'] = df['price'].astype(int)
#
# NameError: name 'df' is not defined

# %%
from sklearn import svm, preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics
from sklearn.metrics import r2_score
from matplotlib import style

# %% [markdown]
# # Distribution of price by date

# %%
df['invoice_date']= pd.to_datetime(df['invoice_date'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 df['invoice_date']= pd.to_datetime(df['invoice_date'])
#
# NameError: name 'df' is not defined

# %%
df.index = df.invoice_date
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 df.index = df.invoice_date
#
# NameError: name 'df' is not defined

# %%
plt.figure(figsize=(20,10))
df.resample('M').customer_id.nunique().plot()
plt.show()

# %%
plt.figure(figsize=(18,10))
df.resample('D').customer_id.nunique().rolling(10).mean().plot()
plt.show()

# %%
plt.figure(figsize=(18,10))
df.resample('M').price.mean().plot()
plt.show()

# %%
fig = px.histogram(df, x='invoice_date', y='price', color='gender',barmode='relative',marginal='box', title='Distribution of the price of goods in shopping centers and the costs of buyers', width=1200, height=600 ,template='plotly_dark')
fig.show()

# %%
## We Will do Age Range Column To help us In Analysis
cut_labels_4 = ['10-20', '21-30', '31-50', '51-70']
cut_bins = [0,20, 30, 50, 71]
df["Age_Range"] =pd.cut(df.Age,
                            bins=cut_bins, 
                         labels=cut_labels_4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 4
#       2 cut_labels_4 = ['10-20', '21-30', '31-50', '51-70']
#       3 cut_bins = [0,20, 30, 50, 71]
# ----> 4 df["Age_Range"] =pd.cut(df.Age,
#       5                             bins=cut_bins,
#       6                          labels=cut_labels_4)
#
# NameError: name 'df' is not defined

# %%
#Average Total Payment For Both Genders
df.groupby('Gender')['Total_payment'].describe()
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked')).History will not be written to the database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 2
#       1 #Average Total Payment For Both Genders
# ----> 2 df.groupby('Gender')['Total_payment'].describe()
#
# NameError: name 'df' is not defined

# %%
#The Correlation Age & Bill Price
df[['Age','Total_payment']].corr()

# %%
px.imshow(df[['Age','Total_payment']].corr(),text_auto=True , color_continuous_scale= 'redor')

# %%
#Average Price for each category
px.box(df , y= 'Price', color='Category')

# %%
#Performance of Malls across years
df5 =df.groupby(['MonthNo','Month','Shopping_mall','Year'])['Total_payment'].sum().reset_index()
df5

# %%
px.bar(df5 , x='Year' , y='Total_payment' , 
       color='Shopping_mall'
      ,barmode='group')
